# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('airbnb_v3.2.csv')
df.head()
# Out:
#                                                Name               Header  \
# 0                  TTS Lake Villa @ Broga, Semenyih    Villa in Semenyih
# 1               TTS Beach Village @ Broga, Semenyih    Villa in Semenyih
# 2       Mountain view villa with entertainment room    Villa in Semenyih
# 3  Wabi Sabian Broga 侘寂の居, わび・さびのい organic farmstay  Cottage in Lenggeng
# 4   Forest House Broga 森の居シンのい sh-in-no-i, Semenyih  Cottage in Lenggeng
#
#   Price_Per_Night  Superhost     Rating      Review  \
# 0        RM1,927   Superhost  4.86 (96)  96 reviews
# 1        RM3,138   Superhost   5.0 (15)  15 reviews
# 2        RM1,716         NaN   4.6 (15)  15 reviews
# 3        RM1,145         NaN  4.86 (22)  22 reviews
# 4        RM1,019         NaN   4.5 (50)  50 reviews
#
#                               Rooms_info  \
# 0  16+ guests 4 bedrooms 15 beds 3 baths
# 1  16+ guests 5 bedrooms 22 beds 6 baths
# 2   16+ guests 6 bedrooms 6 beds 4 baths
# 3     8 guests 2 bedrooms 8 beds 5 baths
# 4   8 guests 2 bedrooms 8 beds 4.5 baths
#
#                                                 Link
# 0  https://www.airbnb.com/rooms/52588088?adults=1...
# 1  https://www.airbnb.com/rooms/73086887394461725...
# 2  https://www.airbnb.com/rooms/61284459437053711...
# 3  https://www.airbnb.com/rooms/60416724063512941...
# 4  https://www.airbnb.com/rooms/45835146?adults=1...

# %%
#Check the summary info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             270 non-null    object
#  1   Header           270 non-null    object
#  2   Price_Per_Night  270 non-null    object
#  3   Superhost        125 non-null    object
#  4   Rating           256 non-null    object
#  5   Review           194 non-null    object
#  6   Rooms_info       269 non-null    object
#  7   Link             270 non-null    object
# dtypes: object(8)
# memory usage: 17.0+ KB

# %% [markdown]
# ## Data Cleaning

# %%
# Check for null value
df.isnull().sum()
# Out:
# Name                 0
# Header               0
# Price_Per_Night      0
# Superhost          145
# Rating              14
# Review              76
# Rooms_info           1
# Link                 0
# dtype: int64

# %%
# Create a new column called area
df['Header'] = df['Header'].astype(str)
df['Area'] = df['Header'].astype(str)
df['Area'] = df['Header'].apply(lambda x: x.split(' in ')[-1])
df['Area'].unique()
# Out:
# array(['Semenyih', 'Lenggeng', 'Broga', 'Kuala Kubu Baru', 'Kajang',
#        'Bangi', 'Nilai', 'Sungai Pelek', 'Seri Kembangan', 'Cyberjaya',
#        'Sepang', 'Seremban', 'Hulu Langat', 'Genting Highlands',
#        'Bandar Baru Bangi', 'Kuala Lumpur', 'Beranang', 'Bentong',
#        'Tanjong Karang', 'Cheras', 'Port Dickson', 'Balakong', 'Mantin',
#        'Petaling Jaya', 'Putrajaya', 'Ampang Jaya', 'Alor Gajah',
#        'Telok Panglima Garang', 'Sekinchan', 'Dengkil', 'Janda Baik',
#        'Batu Caves', 'Subang Jaya', 'Puchong', 'Shah Alam', 'Ampang',
#        'Batang Berjuntai', 'Serendah', 'Pantai'], dtype=object)

# %%
# Create a new column called Home_type
df['Home_type'] = df['Header'].apply(lambda x :x.split(' in ')[0])
df['Home_type']
# Out:
# 0             Villa
# 1             Villa
# 2             Villa
# 3           Cottage
# 4           Cottage
#            ...
# 265       Farm stay
# 266    Private room
# 267          Chalet
# 268       Apartment
# 269           Condo
# Name: Home_type, Length: 270, dtype: object

# %%
df['Home_type'].unique()
# Out:
# array(['Villa', 'Cottage', 'Home', 'Apartment', 'Bungalow', 'Condo',
#        'Guesthouse', 'Vacation home', 'Tiny home', 'Private room',
#        'Place to stay', 'Loft', 'Farm stay', 'Chalet', 'Treehouse',
#        'Hotel room', 'Guest suite', 'Shipping container', 'Resort',
#        'Cabin'], dtype=object)

# %%
df['Price_Per_Night'].unique()
# Out:
# array(['RM1,927 ', 'RM3,138 ', 'RM1,716 ', 'RM1,145 ', 'RM1,019 ',
#        'RM916 ', 'RM358 ', 'RM137 ', 'RM356 ', 'RM890 ', 'RM2,054 ',
#        'RM134 ', 'RM197 ', 'RM898', 'RM228 ', 'RM98 ', 'RM525 ', 'RM156 ',
#        'RM225 ', 'RM222 ', 'RM256 ', 'RM300 ', 'RM253 ', 'RM110',
#        'RM499 ', 'RM297 ', 'RM555 ', 'RM119 ', 'RM344 ', 'RM368 ',
#        'RM123 ', 'RM79 ', 'RM85 ', 'RM64 ', 'RM195 ', 'RM86 ', 'RM94 ',
#        'RM104 ', 'RM115 ', 'RM217 ', 'RM1,255 ', 'RM686', 'RM157 ',
#        'RM99 ', 'RM141 ', 'RM1,096', 'RM97 ', 'RM85', 'RM345 ', 'RM124 ',
#        'RM3,266 ', 'RM470 ', 'RM800 ', 'RM872 ', 'RM335 ', 'RM153 ',
#        'RM114 ', 'RM776 ', 'RM2,995 ', 'RM194 ', 'RM133 ', 'RM105',
#        'RM160 ', 'RM142 ', 'RM93 ', 'RM101', 'RM2,951 ', 'RM442 ',
#        'RM131 ', 'RM262 ', 'RM1,860 ', 'RM3,566 ', 'RM155', 'RM1,232 ',
#        'RM99', 'RM126 ', 'RM1,186', 'RM117 ', 'RM118 ', 'RM971 ',
#        'RM121 ', 'RM1,917', 'RM136', 'RM325 ', 'RM111', 'RM155 ',
#        'RM122 ', 'RM161', 'RM136 ', 'RM102 ', 'RM221', 'RM200 ', 'RM206 ',
#        'RM129 ', 'RM116', 'RM122', 'RM97', 'RM181', 'RM170 ', 'RM176 ',
#        'RM157', 'RM785', 'RM190 ', 'RM221 ', 'RM549 ', 'RM801 ', 'RM405 ',
#        'RM719 ', 'RM251 ', 'RM475', 'RM212 ', 'RM127', 'RM110 ',
#        'RM1,118 ', 'RM88 ', 'RM116 ', 'RM163 ', 'RM773 ', 'RM114',
#        'RM285 ', 'RM137', 'RM130', 'RM201 ', 'RM135 ', 'RM190', 'RM474 ',
#        'RM108 ', 'RM88', 'RM337', 'RM1,522 ', 'RM56 ', 'RM68 ', 'RM171',
#        'RM106 ', 'RM1,133 ', 'RM246 ', 'RM111 ', 'RM655 ', 'RM183 ',
#        'RM179 ', 'RM185 ', 'RM186 ', 'RM803 ', 'RM128', 'RM1,106 ',
#        'RM127 ', 'RM154 ', 'RM128 ', 'RM138 ', 'RM72 ', 'RM109 ', 'RM191',
#        'RM283 ', 'RM86', 'RM629 ', 'RM178', 'RM87 ', 'RM532 ', 'RM151 ',
#        'RM237 ', 'RM144 ', 'RM90 ', 'RM340 ', 'RM129', 'RM973 ', 'RM91 ',
#        'RM194', 'RM969', 'RM302', 'RM164 ', 'RM589 ', 'RM471 ', 'RM140 ',
#        'RM120', 'RM185', 'RM966', 'RM158 ', 'RM582', 'RM551 ', 'RM310 ',
#        'RM196', 'RM1,646 ', 'RM1,712 ', 'RM491 ', 'RM80 ', 'RM67',
#        'RM226 ', 'RM1,690 ', 'RM1,315 ', 'RM207 ', 'RM230 '], dtype=object)

# %%
# Strip the price of the "RM" as well as commas
df['Price_Per_Night'] = df['Price_Per_Night'].apply(lambda x : x.replace(',' ,'').strip('RM'))
df['Price_Per_Night'] = df['Price_Per_Night'].astype(float)

# %%
df['Superhost'].unique()
# Out:
# array(['Superhost', nan], dtype=object)

# %%
# Convert Superhost into 1 and nan into 0
df['Superhost'] = df['Superhost'].apply(lambda x : 1 if x == 'Superhost' else 0)

# %%
# Check for unique values
df['Rating'].unique()
# Out:
# array(['4.86 (96)', '5.0 (15)', '4.6 (15)', '4.86 (22)', '4.5 (50)',
#        '4.82 (124)', '4.89 (28)', '4.74 (116)', '4.9 (40)', '4.94 (80)',
#        '4.83 (12)', '4.56 (18)', '4.85 (27)', '4.88 (199)', '4.86 (14)',
#        '4.64 (42)', '4.76 (200)', '4.63 (43)', '4.96 (55)', '4.83 (30)',
#        '5.0 (6)', '4.85 (33)', '5.0 (19)', '4.97 (39)', '4.95 (38)', nan,
#        '4.71 (7)', '5.0 (4)', '4.85 (54)', '4.8 (5)', '4.51 (59)',
#        '4.89 (9)', 'New', '4.0 (3)', '4.88 (42)', '4.78 (139)',
#        '4.95 (80)', '4.65 (21)', '4.81 (186)', '4.88 (121)', '4.67 (18)',
#        '4.42 (38)', '4.96 (47)', '4.53 (30)', '5.0 (18)', '4.9 (137)',
#        '4.84 (92)', '4.89 (65)', '4.8 (324)', '4.84 (106)', '4.6 (5)',
#        '4.5 (4)', '5.0 (5)', '4.84 (19)', '4.57 (7)', '4.83 (117)',
#        '4.65 (139)', '4.55 (75)', '4.84 (200)', '4.86 (63)', '4.92 (13)',
#        '5.0 (25)', '4.78 (59)', '4.71 (93)', '4.88 (272)', '4.88 (78)',
#        '4.33 (6)', '4.57 (14)', '4.87 (100)', '4.2 (5)', '4.65 (104)',
#        '4.59 (82)', '4.51 (67)', '4.86 (65)', '4.46 (13)', '4.82 (173)',
#        '4.66 (32)', '4.78 (55)', '4.86 (7)', '4.38 (154)', '4.76 (17)',
#        '4.88 (8)', '4.69 (36)', '5.0 (3)', '4.82 (84)', '4.84 (83)',
#        '4.8 (10)', '4.77 (192)', '4.33 (3)', '4.75 (4)', '4.82 (71)',
#        '4.56 (32)', '4.84 (37)', '4.89 (254)', '4.5 (10)', '4.76 (29)',
#        '4.95 (19)', '4.47 (53)', '4.67 (3)', '4.79 (135)', '4.52 (118)',
#        '4.79 (104)', '4.89 (157)', '4.56 (9)', '4.51 (79)', '4.44 (9)',
#        '4.82 (34)', '4.83 (124)', '4.75 (72)', '4.71 (38)', '4.8 (20)',
#        '4.8 (50)', '5.0 (8)', '4.93 (43)', '4.38 (13)', '4.95 (22)',
#        '4.84 (116)', '4.94 (16)', '4.74 (38)', '4.39 (28)', '4.65 (136)',
#        '4.8 (112)', '4.38 (16)', '4.13 (15)', '4.66 (110)', '4.78 (46)',
#        '4.0 (13)', '4.58 (19)', '4.95 (255)', '4.46 (87)', '5.0 (13)',
#        '4.93 (68)', '4.65 (68)', '4.95 (57)', '4.86 (56)', '3.67 (3)',
#        '4.93 (28)', '4.84 (45)', '4.74 (88)'], dtype=object)

# %%
# Remove the review from Rating columns  
df['Rating'] = df['Rating'].astype(str)
df['Rating'] = df['Rating'].apply(lambda x: float(x.split(' ')[0]) if x != "New" else None)

# %%
df['Rating'].unique()
# Out:
# array([4.86, 5.  , 4.6 , 4.5 , 4.82, 4.89, 4.74, 4.9 , 4.94, 4.83, 4.56,
#        4.85, 4.88, 4.64, 4.76, 4.63, 4.96, 4.97, 4.95,  nan, 4.71, 4.8 ,
#        4.51, 4.  , 4.78, 4.65, 4.81, 4.67, 4.42, 4.53, 4.84, 4.57, 4.55,
#        4.92, 4.33, 4.87, 4.2 , 4.59, 4.46, 4.66, 4.38, 4.69, 4.77, 4.75,
#        4.47, 4.79, 4.52, 4.44, 4.93, 4.39, 4.13, 4.58, 3.67])

# %%
df['Rating'].isna().sum()
# Out:
# 76

# %%
# Replacing all the missing values at Rating column
df['Rating'].fillna(0,inplace=True)

# %%
df['Rating'].value_counts()
# Out:
# 0.00    76
# 5.00    35
# 4.86    10
# 4.84    10
# 4.89     8
# 4.80     8
# 4.88     8
# 4.95     7
# 4.65     6
# 4.33     5
# 4.82     5
# 4.78     5
# 4.38     4
# 4.71     4
# 4.79     4
# 4.83     4
# 4.94     4
# 4.00     3
# 4.50     3
# 4.60     3
# 4.93     3
# 4.85     3
# 4.56     3
# 4.51     3
# 4.76     3
# 4.90     3
# 4.74     3
# 4.66     3
# 4.52     2
# 4.77     2
# 4.75     2
# 4.46     2
# 4.81     2
# 4.96     2
# 4.57     2
# 4.67     2
# 4.55     2
# 4.92     1
# 4.58     1
# 4.13     1
# 4.39     1
# 4.64     1
# 4.44     1
# 4.63     1
# 4.97     1
# 4.47     1
# 4.69     1
# 4.42     1
# 4.53     1
# 4.59     1
# 4.20     1
# 4.87     1
# 3.67     1
# Name: Rating, dtype: int64

# %%
df['Review'].isna().sum()
# Out:
# 76

# %%
# Check for unique values for Review column
df['Review'].unique()
# Out:
# array(['96 reviews', '15 reviews', '22 reviews', '50 reviews',
#        '124 reviews', '28 reviews', '116 reviews', '40 reviews',
#        '80 reviews', '12 reviews', '18 reviews', '27 reviews',
#        '199 reviews', '14 reviews', '42 reviews', '200 reviews',
#        '43 reviews', '55 reviews', '30 reviews', '6 reviews',
#        '33 reviews', '19 reviews', '39 reviews', '38 reviews', nan,
#        '7 reviews', '4 reviews', '54 reviews', '5 reviews', '59 reviews',
#        '9 reviews', '3 reviews', '139 reviews', '21 reviews',
#        '186 reviews', '121 reviews', '47 reviews', '137 reviews',
#        '92 reviews', '65 reviews', '324 reviews', '106 reviews',
#        '117 reviews', '75 reviews', '63 reviews', '13 reviews',
#        '25 reviews', '93 reviews', '272 reviews', '78 reviews',
#        '100 reviews', '104 reviews', '82 reviews', '67 reviews',
#        '173 reviews', '32 reviews', '154 reviews', '17 reviews',
#        '8 reviews', '36 reviews', '84 reviews', '83 reviews',
#        '10 reviews', '192 reviews', '71 reviews', '37 reviews',
#        '254 reviews', '29 reviews', '53 reviews', '135 reviews',
#        '118 reviews', '157 reviews', '79 reviews', '34 reviews',
#        '72 reviews', '20 reviews', '16 reviews', '136 reviews',
#        '112 reviews', '110 reviews', '46 reviews', '255 reviews',
#        '87 reviews', '68 reviews', '57 reviews', '56 reviews',
#        '45 reviews', '88 reviews'], dtype=object)

# %%
# Remove reviews and fill the nan value with 0
df['Review'] = df['Review'].astype(str)
df['Review'] = df['Review'].apply(lambda x : x.replace(' reviews',''))
df['Review'] = df['Review'].astype(float)
df['Review'].fillna(0,inplace=True)

# %%
df['Review'].unique()
# Out:
# array([ 96.,  15.,  22.,  50., 124.,  28., 116.,  40.,  80.,  12.,  18.,
#         27., 199.,  14.,  42., 200.,  43.,  55.,  30.,   6.,  33.,  19.,
#         39.,  38.,   0.,   7.,   4.,  54.,   5.,  59.,   9.,   3., 139.,
#         21., 186., 121.,  47., 137.,  92.,  65., 324., 106., 117.,  75.,
#         63.,  13.,  25.,  93., 272.,  78., 100., 104.,  82.,  67., 173.,
#         32., 154.,  17.,   8.,  36.,  84.,  83.,  10., 192.,  71.,  37.,
#        254.,  29.,  53., 135., 118., 157.,  79.,  34.,  72.,  20.,  16.,
#        136., 112., 110.,  46., 255.,  87.,  68.,  57.,  56.,  45.,  88.])

# %%
# Create new columns for Guests
df = df[df['Rooms_info'].notna()]    # remove NaN values in the Rooms_info column 
df['Rooms_info'] = df['Rooms_info'].astype(str)
df['Guests'] = df['Rooms_info'].apply(lambda x: x.split(' ')[0].replace('+', '') if '+' not in x.split(' ')[0] else '16+')

# df['Guests'] = df['Guests'].apply(lambda x: 16 if x == '16+' else int(x))
df['Guests'] = df['Guests'].apply(lambda x: 16 if x == "16+" else int(x) if x != 'nan' else x)

# Convert Guests datatype from str to float
df['Guests'] = df['Guests'].astype(float)

# Fill the Nan values with 0
df['Guests'].fillna(0,inplace=True)

# %%
df['Rooms_info'].unique()
# Out:
# array(['16+ guests 4 bedrooms 15 beds 3 baths',
#        '16+ guests 5 bedrooms 22 beds 6 baths',
#        '16+ guests 6 bedrooms 6 beds 4 baths',
#        '8 guests 2 bedrooms 8 beds 5 baths',
#        '8 guests 2 bedrooms 8 beds 4.5 baths',
#        '12 guests 4 bedrooms 5 beds 3 baths',
#        '8 guests 3 bedrooms 4 beds 2 baths',
#        '7 guests 3 bedrooms 8 beds 2.5 baths',
#        '14 guests 5 bedrooms 8 beds 3 baths',
#        '10 guests 4 bedrooms 4 beds 3 baths',
#        '16+ guests 2 bedrooms 20 beds 5 baths',
#        '6 guests 3 bedrooms 4 beds 2 baths',
#        '10 guests 3 bedrooms 8 beds 3 baths',
#        '4 guests 3 bedrooms 4 beds 2 baths',
#        '2 guests 1 bedroom 1 bed 1 bath',
#        '6 guests 2 bedrooms 4 beds 1 bath',
#        '4 guests Studio 2 beds 1 bath',
#        '5 guests 3 bedrooms 3 beds 2 baths',
#        '7 guests 3 bedrooms 4 beds 2 baths',
#        '4 guests 2 bedrooms 2 beds 1 bath',
#        '6 guests 3 bedrooms 3 beds 2 baths',
#        '7 guests Studio 3 beds 1 bath',
#        '12 guests 4 bedrooms 3 beds 3 baths',
#        '3 guests 1 bedroom 1 bed 1 bath',
#        '12 guests 3 bedrooms 5 beds 2.5 baths',
#        '4 guests 2 bedrooms 2 beds 2 baths',
#        '5 guests 1 bedroom 2 beds 1 bath',
#        '4 guests 2 bedrooms 3 beds 2.5 baths',
#        '8 guests 4 bedrooms 5 beds 3 baths',
#        '2 guests 1 bedroom 1 bed 1.5 baths',
#        '1 guest 1 bedroom 1 bed 1.5 shared baths',
#        '4 guests 1 bedroom 1 bed 1 bath', '2 guests Studio 1 bed 1 bath',
#        '1 guest 1 bedroom 1 bed Shared half-bath',
#        '4 guests Studio 1 bed 1 bath', '3 guests Studio 1 bed 1 bath',
#        '14 guests 4 bedrooms 4 beds 2 baths',
#        '16+ guests 6 bedrooms 6 beds 4.5 baths',
#        '6 guests 2 bedrooms 2 beds 2 baths',
#        '10 guests 3 bedrooms 10 beds 4 baths',
#        '12 guests 5 bedrooms 7 beds 4 baths',
#        '16+ guests 8 bedrooms 16 beds 7 baths',
#        '10 guests 3 bedrooms 3 beds 2.5 baths',
#        '13 guests 4 bedrooms 7 beds 3 baths',
#        '15 guests 4 bedrooms 8 beds 3 baths',
#        '10 guests 4 bedrooms 6 beds 3.5 baths',
#        '4 guests 2 bedrooms 2 beds 1.5 baths',
#        '4 guests 2 bedrooms 1 bath',
#        '16+ guests 7 bedrooms 8 beds 8 baths',
#        '4 guests Studio 4 beds 1 bath',
#        '3 guests 1 bedroom 1 bed 1.5 baths',
#        '16+ guests 8 bedrooms 12 beds 7 baths',
#        '5 guests 2 bedrooms 3 beds 1.5 baths',
#        '10 guests 4 bedrooms 5 beds 3.5 baths',
#        '16+ guests 6 bedrooms 21 beds 6 baths',
#        '5 guests 1 bedroom 1 bed 1 bath',
#        '16+ guests 5 bedrooms 8 beds 4 baths',
#        '16+ guests 4 bedrooms 7 beds 4 baths',
#        '16+ guests 4 bedrooms 6 beds 2 baths',
#        '3 guests Studio 2 beds 2 baths',
#        '16+ guests 4 bedrooms 20 beds 6 baths',
#        '1 guest 1 bedroom 1 bed 2 shared baths',
#        '3 guests 1 bedroom 3 beds 1 bath',
#        '7 guests 2 bedrooms 2 beds 2 baths',
#        '4 guests 1 bedroom 2 beds 1 bath',
#        '2 guests Studio 1 bed 1.5 baths', '3 guests Studio 2 beds 1 bath',
#        '2 guests 1 bedroom 2 beds 1.5 baths',
#        '16+ guests 4 bedrooms 10 beds 2 baths',
#        '10 guests 2 bedrooms 3 beds 2 baths',
#        '8 guests 4 bedrooms 3 beds 4.5 baths',
#        '14 guests 4 bedrooms 7 beds 4 baths',
#        '10 guests 4 bedrooms 5 beds 3 baths',
#        '6 guests 3 bedrooms 3 beds 3 baths',
#        '4 guests 2 bedrooms 3 beds 2 baths',
#        '7 guests 2 bedrooms 6 beds 2 baths',
#        '12 guests 2 bedrooms 2 beds 2 baths',
#        '15 guests 4 bedrooms 9 beds 2 baths', '4 guests Studio 1 bath',
#        '5 guests 2 bedrooms 3 beds 1 bath',
#        '8 guests 2 bedrooms 5 beds 2 baths',
#        '2 guests 1 bedroom 3 beds 1 bath',
#        '10 guests 3 bedrooms 4 beds 2 baths',
#        '10 guests 3 bedrooms 10 beds 3 baths',
#        '1 guest 1 bedroom 1 bed 1 private bath',
#        '6 guests Studio 3 beds 1 bath',
#        '5 guests 1 bedroom 3 beds 1 private bath',
#        '6 guests 2 bedrooms 3 beds 1 bath',
#        '16+ guests 7 bedrooms 14 beds 8 baths',
#        '7 guests 4 bedrooms 5 beds 3.5 baths',
#        '11 guests 4 bedrooms 6 beds 2.5 baths',
#        '3 guests 1 bedroom 2 beds 1 bath',
#        '4 guests 2 bedrooms 2 beds 2.5 baths',
#        '10 guests 3 bedrooms 5 beds 3 baths',
#        '12 guests 5 bedrooms 8 beds 4 baths',
#        '2 guests 1 bedroom 1 bed 1 private bath',
#        '1 guest 1 bedroom 1 bed 1 shared bath',
#        '10 guests 2 bedrooms 7 beds 2 baths',
#        '11 guests 3 bedrooms 4 beds 3 baths',
#        '14 guests 7 bedrooms 7 beds 5 baths',
#        '2 guests 1 bedroom 1 bed 1 shared bath',
#        '16+ guests 4 bedrooms 13 beds 3 baths',
#        '10 guests 3 bedrooms 3 beds 2 baths',
#        '3 guests 1 bedroom 1 bed 1 private bath',
#        '6 guests 1 bedroom 4 beds 1 bath',
#        '16+ guests 6 bedrooms 14 beds 3.5 baths',
#        '5 guests Studio 1 bed 1 bath',
#        '7 guests 2 bedrooms 2 beds 3 baths',
#        '11 guests 3 bedrooms 7 beds 2 baths',
#        '6 guests 2 bedrooms 4 beds 2 baths',
#        '16+ guests 5 bedrooms 10 beds 5 baths',
#        '16+ guests 15 bedrooms 22 beds 14 baths',
#        '4 guests 1 bedroom 2 beds 1 private bath',
#        '2 guests Studio 2 beds 1 bath',
#        '16+ guests 4 bedrooms 6 beds 5 baths',
#        '12 guests 3 bedrooms 6 beds 3 baths'], dtype=object)

# %%
# Create new columns for Bedrooms
df['Bedrooms'] = df['Rooms_info'].apply(lambda x: 1 if len(x.split(' ')) < 3 else (1 if x.split(' ')[2] == 'Studio' else int(x.split(' ')[2])))

# %%
# Create new columns for Beds
# df['Beds'] = df['Rooms_info'].apply(lambda x : x.split(' ')[-4])
df['Beds'] = df['Rooms_info'].apply(lambda x: int(x.split(' ')[-4]) if (len(x.split(' ')) >= 5 and x.split(' ')[-4].isdigit()) else None)
df['Beds'].fillna(value=1, inplace=True)

# %%
# Create new columns for Bathroom
df['Rooms_info2'] = df['Rooms_info'].apply(lambda x: str(x.lower()))
df['Rooms_info2'] = df['Rooms_info'].apply(lambda x: x.replace('shared','').replace('share','').replace('private','').replace('Shared',''))
df['Bathroom'] = df['Rooms_info2'].apply(lambda x: float(x.split(' ')[-2]) if x.split(' ')[-2] != '' else 1)

# %%
# Check for duplicated row and drop the duplicate row
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 269
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             226 non-null    object
#  1   Header           226 non-null    object
#  2   Price_Per_Night  226 non-null    float64
#  3   Superhost        226 non-null    int64
#  4   Rating           226 non-null    float64
#  5   Review           226 non-null    float64
#  6   Rooms_info       226 non-null    object
#  7   Link             226 non-null    object
#  8   Area             226 non-null    object
#  9   Home_type        226 non-null    object
#  10  Guests           226 non-null    float64
#  11  Bedrooms         226 non-null    int64
#  12  Beds             226 non-null    float64
#  13  Rooms_info2      226 non-null    object
#  14  Bathroom         226 non-null    float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 28.2+ KB

# %% [markdown]
# ## Get the longtitude and latitude coordinate for each Area

# %%
#Add lat & long into the dataframe
df['Latitude'] =np.nan
df['Longitude'] =np.nan
df.head(5)
# Out:
#                                                Name               Header  \
# 0                  TTS Lake Villa @ Broga, Semenyih    Villa in Semenyih
# 1               TTS Beach Village @ Broga, Semenyih    Villa in Semenyih
# 2       Mountain view villa with entertainment room    Villa in Semenyih
# 3  Wabi Sabian Broga 侘寂の居, わび・さびのい organic farmstay  Cottage in Lenggeng
# 4   Forest House Broga 森の居シンのい sh-in-no-i, Semenyih  Cottage in Lenggeng
#
#    Price_Per_Night  Superhost  Rating  Review  \
# 0           1927.0          1    4.86    96.0
# 1           3138.0          1    5.00    15.0
# 2           1716.0          0    4.60    15.0
# 3           1145.0          0    4.86    22.0
# 4           1019.0          0    4.50    50.0
#
#                               Rooms_info  \
# 0  16+ guests 4 bedrooms 15 beds 3 baths
# 1  16+ guests 5 bedrooms 22 beds 6 baths
# 2   16+ guests 6 bedrooms 6 beds 4 baths
# 3     8 guests 2 bedrooms 8 beds 5 baths
# 4   8 guests 2 bedrooms 8 beds 4.5 baths
#
#                                                 Link      Area Home_type  \
# 0  https://www.airbnb.com/rooms/52588088?adults=1...  Semenyih     Villa
# 1  https://www.airbnb.com/rooms/73086887394461725...  Semenyih     Villa
# 2  https://www.airbnb.com/rooms/61284459437053711...  Semenyih     Villa
# 3  https://www.airbnb.com/rooms/60416724063512941...  Lenggeng   Cottage
# 4  https://www.airbnb.com/rooms/45835146?adults=1...  Lenggeng   Cottage
#
#    Guests  Bedrooms  Beds                            Rooms_info2  Bathroom  \
# 0    16.0         4  15.0  16+ guests 4 bedrooms 15 beds 3 baths       3.0
# 1    16.0         5  22.0  16+ guests 5 bedrooms 22 beds 6 baths       6.0
# 2    16.0         6   6.0   16+ guests 6 bedrooms 6 beds 4 baths       4.0
# 3     8.0         2   8.0     8 guests 2 bedrooms 8 beds 5 baths       5.0
# 4     8.0         2   8.0   8 guests 2 bedrooms 8 beds 4.5 baths       4.5
#
#    Latitude  Longitude
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='Malaysia')
location = []
i=0
for d in df['Area']:
    address = d+',  MY'    
    location.append(geolocator.geocode(address))
    if location[i] is None:
        print('Coordinates of ', d, ' are missing')
    else :
        print('Coordinates of ', d, ' are:', location[i].latitude, location[i].longitude)
        df['Latitude'].iloc[i] = geolocator.geocode(address).latitude
        df['Longitude'].iloc[i] = geolocator.geocode(address).longitude
    i=i+1
# Out:
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# C:\Users\ACER\AppData\Local\Temp/ipykernel_4408/3785663507.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Latitude'].iloc[i] = geolocator.geocode(address).latitude
# C:\Users\ACER\AppData\Local\Temp/ipykernel_4408/3785663507.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Longitude'].iloc[i] = geolocator.geocode(address).longitude
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Lenggeng  are: 2.861427 101.943388
# Coordinates of  Lenggeng  are: 2.861427 101.943388
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Broga  are: 2.9365953 101.9111952
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Kuala Kubu Baru  are: 3.6371407 101.5730051
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Kuala Kubu Baru  are: 3.6371407 101.5730051
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Bangi  are: 2.90398245 101.78602883608005
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Lenggeng  are: 2.861427 101.943388
# Coordinates of  Sungai Pelek  are: 2.6449074 101.7170375
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Sepang  are: 2.76020875 101.73686570150568
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Lenggeng  are: 2.861427 101.943388
# Coordinates of  Seremban  are: 2.7187881 101.9404509
# Coordinates of  Hulu Langat  are: 3.083333 101.833333
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Broga  are: 2.9365953 101.9111952
# Coordinates of  Bangi  are: 2.90398245 101.78602883608005
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Beranang  are: 2.8746114 101.8719856
# Coordinates of  Sepang  are: 2.76020875 101.73686570150568
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Tanjong Karang  are: 3.3959421499999998 101.21700553434212
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Beranang  are: 2.8746114 101.8719856
# Coordinates of  Hulu Langat  are: 3.083333 101.833333
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Cheras  are: 3.0991919 101.7374229
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Hulu Langat  are: 3.083333 101.833333
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Bangi  are: 2.90398245 101.78602883608005
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Balakong  are: 3.0291306 101.7472119
# Coordinates of  Sepang  are: 2.76020875 101.73686570150568
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Mantin  are: 2.825719 101.893793
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Broga  are: 2.9365953 101.9111952
# Coordinates of  Cheras  are: 3.0991919 101.7374229
# Coordinates of  Petaling Jaya  are: 3.0991752 101.6450232
# Coordinates of  Petaling Jaya  are: 3.0991752 101.6450232
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Cheras  are: 3.0991919 101.7374229
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Putrajaya  are: 2.9140567 101.6838531
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Cheras  are: 3.0991919 101.7374229
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Ampang Jaya  are: 3.1276087 101.7538639
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Alor Gajah  are: 2.3834528 102.2107805
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Telok Panglima Garang  are: 2.91076905 101.46929508218227
# Coordinates of  Petaling Jaya  are: 3.0991752 101.6450232
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Sekinchan  are: 3.5002934 101.10623
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Kuala Kubu Baru  are: 3.6371407 101.5730051
# Coordinates of  Sepang  are: 2.76020875 101.73686570150568
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Alor Gajah  are: 2.3834528 102.2107805
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Sekinchan  are: 3.5002934 101.10623
# Coordinates of  Dengkil  are: 2.8680243 101.6756275
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Janda Baik  are: 3.3227606 101.8486758
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Lenggeng  are: 2.861427 101.943388
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Cyberjaya  are: 2.9338908 101.6455587
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Balakong  are: 3.0291306 101.7472119
# Coordinates of  Alor Gajah  are: 2.3834528 102.2107805
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Dengkil  are: 2.8680243 101.6756275
# Coordinates of  Bangi  are: 2.90398245 101.78602883608005
# Coordinates of  Putrajaya  are: 2.9140567 101.6838531
# Coordinates of  Dengkil  are: 2.8680243 101.6756275
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Batu Caves  are: 3.2377961500000003 101.68138011062376
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Sepang  are: 2.76020875 101.73686570150568
# Coordinates of  Bandar Baru Bangi  are: 2.9540793 101.78100179726445
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Subang Jaya  are: 3.051487 101.5823339
# Coordinates of  Hulu Langat  are: 3.083333 101.833333
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Puchong  are: 3.0342324 101.6170345
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Ampang Jaya  are: 3.1276087 101.7538639
# Coordinates of  Putrajaya  are: 2.9140567 101.6838531
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Shah Alam  are: 3.0733644 101.5195149
# Coordinates of  Kuala Kubu Baru  are: 3.6371407 101.5730051
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Ampang  are: 3.15025555 101.76021009194159
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Batang Berjuntai  are: 3.378008 101.4102245
# Coordinates of  Genting Highlands  are: 3.4237725 101.7935591
# Coordinates of  Serendah  are: 3.3651433 101.6033076
# Coordinates of  Pantai  are: 2.7815196 101.9931586
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Alor Gajah  are: 2.3834528 102.2107805
# Coordinates of  Seri Kembangan  are: 3.0340649 101.7055684
# Coordinates of  Kajang  are: 2.9948437 101.7896595
# Coordinates of  Seremban  are: 2.7187881 101.9404509
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371
# Coordinates of  Bentong  are: 3.3624708 102.0172675
# Coordinates of  Puchong  are: 3.0342324 101.6170345
# Coordinates of  Lenggeng  are: 2.861427 101.943388
# Coordinates of  Shah Alam  are: 3.0733644 101.5195149
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Nilai  are: 2.8023079 101.7995013
# Coordinates of  Sepang  are: 2.76020875 101.73686570150568
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Mantin  are: 2.825719 101.893793
# Coordinates of  Semenyih  are: 2.9473911 101.8459911
# Coordinates of  Port Dickson  are: 2.5228943 101.7945134
# Coordinates of  Kuala Lumpur  are: 3.1516964 101.6942371

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 269
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             226 non-null    object
#  1   Header           226 non-null    object
#  2   Price_Per_Night  226 non-null    float64
#  3   Superhost        226 non-null    int64
#  4   Rating           226 non-null    float64
#  5   Review           226 non-null    float64
#  6   Rooms_info       226 non-null    object
#  7   Link             226 non-null    object
#  8   Area             226 non-null    object
#  9   Home_type        226 non-null    object
#  10  Guests           226 non-null    float64
#  11  Bedrooms         226 non-null    int64
#  12  Beds             226 non-null    float64
#  13  Rooms_info2      226 non-null    object
#  14  Bathroom         226 non-null    float64
#  15  Latitude         226 non-null    float64
#  16  Longitude        226 non-null    float64
# dtypes: float64(8), int64(2), object(7)
# memory usage: 31.8+ KB

# %%
df.tail()
# Out:
#                                                   Name  \
# 264                      Aurora Home with Private Pool
# 265                    Rumah Kebun @ Trigofarm Retreat
# 266     Jiaxin Homestay Semenyih Broga Kajang Selangor
# 267          Tokido Executive Water Villa Private Unit
# 269  Cozy Little Muji Home Kepong Nice View MRT E03A D
#
#                        Header  Price_Per_Night  Superhost  Rating  Review  \
# 264     Villa in Port Dickson           1690.0          1    4.93    28.0
# 265       Farm stay in Mantin           1315.0          1    4.84    45.0
# 266  Private room in Semenyih            207.0          0    0.00     0.0
# 267    Chalet in Port Dickson            470.0          0    4.74    88.0
# 269     Condo in Kuala Lumpur            230.0          1    0.00     0.0
#
#                                Rooms_info  \
# 264  16+ guests 4 bedrooms 6 beds 5 baths
# 265   12 guests 3 bedrooms 6 beds 3 baths
# 266    2 guests 1 bedroom 1 bed 1.5 baths
# 267      4 guests 1 bedroom 2 beds 1 bath
# 269    7 guests 3 bedrooms 4 beds 2 baths
#
#                                                   Link          Area  \
# 264  https://www.airbnb.com/rooms/47280968?adults=1...  Port Dickson
# 265  https://www.airbnb.com/rooms/35548563?adults=1...        Mantin
# 266  https://www.airbnb.com/rooms/34833256?adults=1...      Semenyih
# 267  https://www.airbnb.com/rooms/37679839?adults=1...  Port Dickson
# 269  https://www.airbnb.com/rooms/81712786780072672...  Kuala Lumpur
#
#         Home_type  Guests  Bedrooms  Beds  \
# 264         Villa    16.0         4   6.0
# 265     Farm stay    12.0         3   6.0
# 266  Private room     2.0         1   1.0
# 267        Chalet     4.0         1   2.0
# 269         Condo     7.0         3   4.0
#
#                               Rooms_info2  Bathroom  Latitude   Longitude
# 264  16+ guests 4 bedrooms 6 beds 5 baths       5.0  2.522894  101.794513
# 265   12 guests 3 bedrooms 6 beds 3 baths       3.0  2.825719  101.893793
# 266    2 guests 1 bedroom 1 bed 1.5 baths       1.5  2.947391  101.845991
# 267      4 guests 1 bedroom 2 beds 1 bath       1.0  2.522894  101.794513
# 269    7 guests 3 bedrooms 4 beds 2 baths       2.0  3.151696  101.694237

# %%
#Save Preprocessed Data
df.to_csv('Airbnb_cleanv1.csv')
